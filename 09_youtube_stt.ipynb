# %%
# !pip install
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.0.10.2 Requires-Python >=3.6.0, <3.9; 0.0.10.3 Requires-Python >=3.6.0, <3.9; 0.0.11 Requires-Python >=3.6.0, <3.9; 0.0.12 Requires-Python >=3.6.0, <3.9; 0.0.13.1 Requires-Python >=3.6.0, <3.9; 0.0.13.2 Requires-Python >=3.6.0, <3.9; 0.0.14.1 Requires-Python >=3.6.0, <3.9; 0.0.15 Requires-Python >=3.6.0, <3.9; 0.0.15.1 Requires-Python >=3.6.0, <3.9; 0.0.9 Requires-Python >=3.6.0, <3.9; 0.0.9.1 Requires-Python >=3.6.0, <3.9; 0.0.9.2 Requires-Python >=3.6.0, <3.9; 0.0.9a10 Requires-Python >=3.6.0, <3.9; 0.0.9a9 Requires-Python >=3.6.0, <3.9; 0.1.0 Requires-Python >=3.6.0, <3.10; 0.1.1 Requires-Python >=3.6.0, <3.10; 0.1.2 Requires-Python >=3.6.0, <3.10; 0.1.3 Requires-Python >=3.6.0, <3.10; 0.10.0 Requires-Python >=3.7.0, <3.11; 0.10.1 Requires-Python >=3.7.0, <3.11; 0.10.2 Requires-Python >=3.7.0, <3.11; 0.11.0 Requires-Python >=3.7.0, <3.11; 0.11.1 Requires-Python >=3.7.0, <3.11; 0.12.0 Requires-Python >
# ...

# %%
# !pip install git+https://github.com/openai/whisper
# Out:
# ...
#   Cloning https://github.com/openai/whisper to c:\users\playdata\appdata\local\temp\pip-req-build-ya1ty7_8
#   Resolved https://github.com/openai/whisper to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 82.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ------------------------------ --------- 23.1/30.3 MB 104.1 MB/s eta 0:00:01
#    ---------------------------------------- 30.3/30.3 MB 91.4 MB/s eta 0:00:00
# ...

# %%
import yt_dlp
url = 'https://www.youtube.com/watch?v=VQa6yYqa2MU'
output_path = 'youtube_output'

ydl_opts={
    "format": "bestaudio/best",
    "ottmpl": output_path,
    "postprocessors": [{
        "key": "FFmpegExtractAudio",
        "preferredcodec": "mp3",
        "preferredquality": "192"
    }]
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])

print(output_path,"mp3 파일 다운로드 완료")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VQa6yYqa2MU
# [youtube] VQa6yYqa2MU: Downloading webpage
# [youtube] VQa6yYqa2MU: Downloading tv simply player API JSON
# [youtube] VQa6yYqa2MU: Downloading tv client config
# [youtube] VQa6yYqa2MU: Downloading player 6742b2b9-main
# [youtube] VQa6yYqa2MU: Downloading tv player API JSON
# [info] VQa6yYqa2MU: Downloading 1 format(s): 251
# [download] Sleeping 3.00 seconds as required by the site...
# [download] Destination: 영상에서 꼬순내가 진동함 ㄷㄷ ｜ 견종백과 말티푸편 [VQa6yYqa2MU].webm
# [download] 100% of    6.47MiB in 00:00:00 at 42.69MiB/s
# [ExtractAudio] Destination: 영상에서 꼬순내가 진동함 ㄷㄷ ｜ 견종백과 말티푸편 [VQa6yYqa2MU].mp3
# Deleting original file 영상에서 꼬순내가 진동함 ㄷㄷ ｜ 견종백과 말티푸편 [VQa6yYqa2MU].webm (pass -k to keep)
# youtube_output mp3 파일 다운로드 완료

# %%
import whisper

model = whisper.load_model('small')
result = model.transcribe("youtube_output.mp3")
result
# Out:
# {'text': ' 같은 말티프지만 딱 열어보면 이게 말티즈로 다 나올 수도 있어요 푸들로 나올 수도 있고 이거 뭐 랜덤박스야 뭐야 우리끼리만 살짝 하는 얘기지만 말티즈가 조금 많이 들어가면 조금 힘들어요 Q. 말티프의 인기? 안녕하세요 훈련사 강혁입니다 제가 이 말티프의 인기에 졌습니다 견종이 아닌데 어떻게 견종백가에서 소개를 하나? 제가 이런 적이 있었는데요 그냥 딱 한 눈에 봐도 말티푸들이 너무 많아져가지고 말티프를 한번 소개해 드려야 되겠다라고 했습니다 얘가 콩떡이라고 하고요 얘는 콧떡이라고 합니다 약간 두 마리의 차이가 있는데요 지금 이 친구는 털이 약간 조금 더 이렇게 웨이브가 적고요 이 친구는 털이 조금 더 스트레이트입니다 이걸 보면은 조금 알 수 있는 게 우리 같은 말티프이기는 하지만 우리 이 친구는 말티프가 조금 더 많이 들어간 것 같고 이 친구는 푸들이 좀 많이 들어간 것 같은 느낌이 들기도 합니다 제가 저번에 그 골든 도둘 때도 잠깐 말씀드렸지만 전 세계적으로 푸돌 믹스들이 인기가 진짜 많아요 실제로 말티프는 미국에서부터 인기가 많았다고 하고요 그 외에 서구권에서 원래 인기가 굉장히 많았었답니다 다른 친구들보다 애교도 많고 친화력도 좋고 알레르기를 일으키는 그 위험도도 좀 낫다고 합니다 푸돌의 장점과 말티지의 장점이 고루고루고루 섞여서 말티프가 됐습니다 우리나라에서 푸돌이 하얀색 푸돌이 인기가 많았었는데 어느 순간 그 갈색 푸돌의 인기가 팍 치고 올라갔던 시기가 있었어요 하얀색 말티지하고 결혼을 하니까 색이 조금 옅어져가지고 라떼라는 이름에 자 라떼 한번 손 들어보세요 지금 이거 보시고 있는 분들도 라떼 많을걸요 말티푸들 라떼 진짜 많아요 또 보리 손 들어보세요 보리 아 보리도 많을 거예요 푸돌 중에서도 이런 색깔의 푸들이 있어요 어머나 이런 색깔의 푸들하고 말티지하고 결혼을 했는데 말티푼데 이런 색깔도 나오고 빨간색 푸돌하고 말티지하고 교배를 했는데 어머나 라떼 색깔이 나오네 검정색 푸돌하고 하얀색 말티지하고 이렇게 결혼을 하면 회색이
# ...

# %%
result['text']
# Out:
# ' 같은 말티프지만 딱 열어보면 이게 말티즈로 다 나올 수도 있어요 푸들로 나올 수도 있고 이거 뭐 랜덤박스야 뭐야 우리끼리만 살짝 하는 얘기지만 말티즈가 조금 많이 들어가면 조금 힘들어요 Q. 말티프의 인기? 안녕하세요 훈련사 강혁입니다 제가 이 말티프의 인기에 졌습니다 견종이 아닌데 어떻게 견종백가에서 소개를 하나? 제가 이런 적이 있었는데요 그냥 딱 한 눈에 봐도 말티푸들이 너무 많아져가지고 말티프를 한번 소개해 드려야 되겠다라고 했습니다 얘가 콩떡이라고 하고요 얘는 콧떡이라고 합니다 약간 두 마리의 차이가 있는데요 지금 이 친구는 털이 약간 조금 더 이렇게 웨이브가 적고요 이 친구는 털이 조금 더 스트레이트입니다 이걸 보면은 조금 알 수 있는 게 우리 같은 말티프이기는 하지만 우리 이 친구는 말티프가 조금 더 많이 들어간 것 같고 이 친구는 푸들이 좀 많이 들어간 것 같은 느낌이 들기도 합니다 제가 저번에 그 골든 도둘 때도 잠깐 말씀드렸지만 전 세계적으로 푸돌 믹스들이 인기가 진짜 많아요 실제로 말티프는 미국에서부터 인기가 많았다고 하고요 그 외에 서구권에서 원래 인기가 굉장히 많았었답니다 다른 친구들보다 애교도 많고 친화력도 좋고 알레르기를 일으키는 그 위험도도 좀 낫다고 합니다 푸돌의 장점과 말티지의 장점이 고루고루고루 섞여서 말티프가 됐습니다 우리나라에서 푸돌이 하얀색 푸돌이 인기가 많았었는데 어느 순간 그 갈색 푸돌의 인기가 팍 치고 올라갔던 시기가 있었어요 하얀색 말티지하고 결혼을 하니까 색이 조금 옅어져가지고 라떼라는 이름에 자 라떼 한번 손 들어보세요 지금 이거 보시고 있는 분들도 라떼 많을걸요 말티푸들 라떼 진짜 많아요 또 보리 손 들어보세요 보리 아 보리도 많을 거예요 푸돌 중에서도 이런 색깔의 푸들이 있어요 어머나 이런 색깔의 푸들하고 말티지하고 결혼을 했는데 말티푼데 이런 색깔도 나오고 빨간색 푸돌하고 말티지하고 교배를 했는데 어머나 라떼 색깔이 나오네 검정색 푸돌하고 하얀색 말티지하고 이렇게 결혼을 하면 회색이 나올 수도 있습
# ...

# %%
# for idx, temp in enumerate(result['segments']):
#     !ffmpeg -y -i youtube_output.mp3 -ss {temp['start']} -to {temp['end']} -hide_banner -loglevel error wavs/audio{idx+1}.wav

for idx, temp in enumerate(result['segments']):
    cmd = f"ffmpeg -y -i youtube_output.mp3 -ss {temp['start']} -to {temp['end']} -hide_banner -loglevel error wavs/audio{idx+1}.wav"
    # !{cmd}
# Out:
# ^C
# ^C

# %%
from IPython.display import Audio
Audio('wavs/audio55.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install coqui-tts
# Out:
# ...
#      ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#      ---------------------------------------- 3.7/3.7 MB 56.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      --------------------------------------  15.2/15.3 MB 73.2 MB/s eta 0:00:01
#      --------------------------------------- 15.3/15.3 MB 68.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
from TTS.api import TTS


TTS(model_name='tts_models/multilingual/multi-dataset/xtts_v2')
# Out:
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
# 100%|██████████| 1.87G/1.87G [00:40<00:00, 46.2MiB/s]
# 4.37kiB [00:00, 9.73kiB/s]
# 361kiB [00:00, 801kiB/s]
# 100%|██████████| 32.0/32.0 [00:00<00:00, 48.1iB/s]
#  72%|███████▏  | 5.56M/7.75M [00:00<00:00, 48.1MiB/s]
# TTS(
#   (synthesizer): Synthesizer(
#     (tts_model): Xtts(
#       (gpt): GPT(
#         (conditioning_encoder): ConditioningEncoder(
#           (init): Conv1d(80, 1024, kernel_size=(1,), stride=(1,))
#           (attn): Sequential(
#             (0): AttentionBlock(
#               (norm): GroupNorm32(32, 1024, eps=1e-05, affine=True)
#               (qkv): Conv1d(1024, 3072, kernel_size=(1,), stride=(1,))
#               (attention): QKVAttentionLegacy()
#               (proj_out): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#             )
# ...

# %%
# !pip install hangul-romanize

# %%
tts.tts_to_file(
    text='열심히 공부해야 멋진 사람이 될 수 있어요!',
    file_path='youtube_tts_output.wav',
    language="ko",
    speaker_wav=['wavs/audio55.wav'],
    split_sentences=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 tts.tts_to_file(
#       2     text='열심히 공부해야 멋진 사람이 될 수 있어요!',
#       3     file_path='youtube_tts_output.wav',
#       4     language="ko",
#       5     speaker_wav=['wavs/audio55.wav'],
#       6     split_sentences=True
#       7 )
#
# NameError: name 'tts' is not defined
